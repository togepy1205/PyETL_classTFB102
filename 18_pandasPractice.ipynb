# %%
# !pip install pandas

# %%
import pandas as pd
import glob # 跟 os 一樣有開啟檔案輸入資料的功能

glob.glob('./res_gossiping/*.txt') # unix style
# Out:
# ['./res_gossiping\\[公告] 523新增違規案例及上周校正回歸個案 水桶.txt',
#  './res_gossiping\\[公告] 八卦板板規(2021.05.11).txt',
#  './res_gossiping\\[公告] 周六新增大量校正回歸水桶案例.txt',
#  './res_gossiping\\[公告] 置底大怒灌Hate閒聊區.txt',
#  './res_gossiping\\[問卦]   想打上海復星BNT的請進.txt',
#  './res_gossiping\\[問卦]  人一綠就腦殘 誰贊成誰反對.txt',
#  './res_gossiping\\[問卦]  出門去沒人的地方會變防疫破口嗎？.txt',
#  './res_gossiping\\[問卦]  校正回歸真正的影響？.txt',
#  './res_gossiping\\[問卦] 100年後台灣歷史課本怎麼形容2021年？.txt',
#  './res_gossiping\\[問卦] 228白色恐怖是為了救台灣吧？.txt',
#  './res_gossiping\\[問卦] 3+11的真相背後的真相.txt',
#  './res_gossiping\\[問卦] 300萬能幹嘛.txt',
#  './res_gossiping\\[問卦] 30歲要如何吸引女人的八卦.txt',
#  './res_gossiping\\[問卦] 484應該要還給新一代一個公道.txt',
#  './res_gossiping\\[問卦] 5月31日有可能開學嗎？.txt',
#  './res_gossiping\\[問卦] =.= 疫情宅在家每天螢幕9小時！？.txt',
#  './res_gossiping\\[問卦] BNT疫苗打一劑要一萬 你打嗎.txt',
#  './res_gossiping\\[問卦] Donki Donki 老闆現在在想什麼.txt',
#  './res_gossiping\\[問卦] PTT是什麼？？.txt',
#  './res_gossiping\\[問卦] 「地方」檢驗的到底是哪個地方？.txt',
#  './res_gossiping\\[問卦] 「開放討論」是側翼之語嗎？.txt',
# ...

# %%
glob.glob('./0[3-8]*.ipynb') # 可用正規表達式篩選要的資料
# Out:
# ['.\\03_requestPractice.ipynb',
#  '.\\04_beautifulSoupPractice.ipynb',
#  '.\\05_pttMovieOnePage.ipynb',
#  '.\\06_pttMovieMultiPage.ipynb',
#  '.\\07_MovieMultiPage2.ipynb',
#  '.\\08_postPractice.ipynb']

# %%
# 只有 Jupyter Notebook 會顯示出來, 其他 IDE 不會
df = pd.DataFrame(columns= ['Name', 'Age', 'Height'])
df
# Out:
# Empty DataFrame
# Columns: [Name, Age, Height]
# Index: []

# %%
# 新增一列
df.loc[0] = ['Allen', '22', '175']
df
# Out:
#     Name Age Height
# 0  Allen  22    175

# %%
df.loc[1] = ['Ted', '25', '180']
df
# Out:
#     Name Age Height
# 0  Allen  22    175
# 1    Ted  25    180

# %%
# 新增一欄資料
df['Weight']=['75','80']
df
# Out:
#     Name Age Height Weight
# 0  Allen  22    175     75
# 1    Ted  25    180     80

# %%
# 刪掉一欄
df.drop(['Weight'], axis=1) # axis 刪除的方向: 1 為直, 0 為橫
# Out:
#     Name Age Height
# 0  Allen  22    175
# 1    Ted  25    180

# %%
df # 並不會馬上刪除
# Out:
#     Name Age Height Weight
# 0  Allen  22    175     75
# 1    Ted  25    180     80

# %%
df = df.drop(['Weight'], axis=1)
df
# Out:
#     Name Age Height
# 0  Allen  22    175
# 1    Ted  25    180

# %%
df.drop(1, axis=0)
# Out:
#     Name Age Height
# 0  Allen  22    175

# %%
df
# Out:
#     Name Age Height
# 0  Allen  22    175
# 1    Ted  25    180

# %%
df['Height'][0]

# %%
df['Height'][0] = '178'
# Out:
#     Name Age Height
# 0  Allen  22    178
# 1    Ted  25    180

# %%
df

# %%
df['Height']

# %%
df['Height'] = '123'
df
# Out:
#     Name Age Height
# 0  Allen  22    123
# 1    Ted  25    123

# %%
df

# %%
df.loc[0] = 'aaa'
# Out:
#   Name  Age Height
# 0  aaa  aaa    aaa
# 1  Ted   25    123

# %%
df
# Out:
#      Name  Age Height
# 0     aaa  aaa    aaa
# 1     Ted   25    123
# 0  Allen2   22    175
# 1    Ted2   25    180

# %%
columns = ['Name', 'Age', 'Height']
data = [
    ['Allen2', '22', '175'],
    ['Ted2', '25', '180']
]
df2 = pd.DataFrame(data=data, columns=columns)
df2
# Out:
#      Name Age Height
# 0  Allen2  22    175
# 1    Ted2  25    180

# %%
df.append(df2)
# Out:
#      Name  Age Height
# 0     aaa  aaa    aaa
# 1     Ted   25    123
# 0  Allen2   22    175
# 1    Ted2   25    180

# %%
df
# Out:
#   Name  Age Height
# 0  aaa  aaa    aaa
# 1  Ted   25    123

# %%
df = df.append(df2)
df
# Out:
#      Name  Age Height
# 0     aaa  aaa    aaa
# 1     Ted   25    123
# 0  Allen2   22    175
# 1    Ted2   25    180

# %%
df.reset_index()
# Out:
#    index    Name  Age Height
# 0      0     aaa  aaa    aaa
# 1      1     Ted   25    123
# 2      0  Allen2   22    175
# 3      1    Ted2   25    180

# %%
df.reset_index(drop=True)

# %%
df

# %%
df.reset_index(drop=True)
df
# Out:
#      Name  Age Height
# 0     aaa  aaa    aaa
# 1     Ted   25    123
# 0  Allen2   22    175
# 1    Ted2   25    180
